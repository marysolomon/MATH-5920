# %%
### The 3N + 1 game ###
"""
The game "3N+1" goes like this.  If N is odd, multiply it by 3 and add 1.  If N is even, divide it by 2.  
Repeat until N equals 1, if ever.  Every value of N that anyone has ever checked eventually leads to 1, 
but it is an open mathematical problem (known as the Collatz conjecture) whether EVERY value of N 
eventually leads to 1.  You can read about it on Wikipedia.  

Before you start working on these programs, take a sheet of paper and write out what happens 
when you start with N=5, N=6, N=7, N=9, to get a feel for it.  For example, starting with N=6, 
the next number is 3, then 10, then 5, then 16, 8, 4, 2, 1 and we are done.
"""

# %%
### Three n ###
"""
Write a program called three_n that defines a starting value of N and plays the game "3N+1" 
and prints to the screen the values of N visited along the way.  Use a while loop and stop when N=1.  
Investigate some starting values of N.  N=27 is particularly interesting. 
"""
N = 27
while N != 1:
    if N%2 == 0:
        N = N /2
    else:
        N = 3*N + 1
    print(N)
# Out:
# 82
# 41.0
# 124.0
# 62.0
# 31.0
# 94.0
# 47.0
# 142.0
# 71.0
# 214.0
# 107.0
# 322.0
# 161.0
# 484.0
# 242.0
# 121.0
# 364.0
# 182.0
# 91.0
# 274.0
# 137.0
# 412.0
# 206.0
# 103.0
# 310.0
# 155.0
# 466.0
# 233.0
# 700.0
# 350.0
# 175.0
# 526.0
# 263.0
# 790.0
# 395.0
# 1186.0
# 593.0
# 1780.0
# 890.0
# 445.0
# 1336.0
# 668.0
# 334.0
# 167.0
# 502.0
# 251.0
# 754.0
# 377.0
# 1132.0
# 566.0
# 283.0
# 850.0
# 425.0
# 1276.0
# 638.0
# 319.0
# 958.0
# 479.0
# 1438.0
# 719.0
# 2158.0
# 1079.0
# 3238.0
# 1619.0
# 4858.0
# 2429.0
# 7288.0
# 3644.0
# 1822.0
# 911.0
# 2734.0
# 1367.0
# 4102.0
# 2051.0
# 6154.0
# 3077.0
# 9232.0
# 4616.0
# 2308.0
# 1154.0
# 577.0
# 1732.0
# 866.0
# 433.0
# 1300.0
# 650.0
# 325.0
# 976.0
# 488.0
# 244.0
# 122.0
# 61.0
# 184.0
# 92.0
# 46.0
# 23.0
# 70.0
# 35.0
# 106.0
# 53.0
# 160.0
# 80.0
# 40.0
# 20.0
# 10.0
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0

# %%
"""
Introduce an additional variable to count how many steps are needed to get to 1, 
and have the program print that counter after it arrives at N=1.
"""

N = 27
i = 0
while N != 1:
    if N%2 == 0:
        N = N /2
    else:
        N = 3*N + 1
    print(N)
    i += 1
print("It takes %d steps to arrive at N = 1" % i)
# Out:
# 82
# 41.0
# 124.0
# 62.0
# 31.0
# 94.0
# 47.0
# 142.0
# 71.0
# 214.0
# 107.0
# 322.0
# 161.0
# 484.0
# 242.0
# 121.0
# 364.0
# 182.0
# 91.0
# 274.0
# 137.0
# 412.0
# 206.0
# 103.0
# 310.0
# 155.0
# 466.0
# 233.0
# 700.0
# 350.0
# 175.0
# 526.0
# 263.0
# 790.0
# 395.0
# 1186.0
# 593.0
# 1780.0
# 890.0
# 445.0
# 1336.0
# 668.0
# 334.0
# 167.0
# 502.0
# 251.0
# 754.0
# 377.0
# 1132.0
# 566.0
# 283.0
# 850.0
# 425.0
# 1276.0
# 638.0
# 319.0
# 958.0
# 479.0
# 1438.0
# 719.0
# 2158.0
# 1079.0
# 3238.0
# 1619.0
# 4858.0
# 2429.0
# 7288.0
# 3644.0
# 1822.0
# 911.0
# 2734.0
# 1367.0
# 4102.0
# 2051.0
# 6154.0
# 3077.0
# 9232.0
# 4616.0
# 2308.0
# 1154.0
# 577.0
# 1732.0
# 866.0
# 433.0
# 1300.0
# 650.0
# 325.0
# 976.0
# 488.0
# 244.0
# 122.0
# 61.0
# 184.0
# 92.0
# 46.0
# 23.0
# 70.0
# 35.0
# 106.0
# 53.0
# 160.0
# 80.0
# 40.0
# 20.0
# 10.0
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0
# It takes 111 steps to arrive at N = 1

# %%
"""
Introduce an additional variable to keep track of the maximum value of N before the program reaches N=1.
Here is the logic:  Before the while loop, set m=0.  Within the while loop, if N > m, set m equal to N.  
"""

N = 27
i = 1
m = 0
while N != 1:
    if N%2 == 0:
        N = N /2
    else:
        N = 3*N + 1
    print(N)
    if N > m:
        m = N
    print("The maximum value of N is %d" % m)
    i += 1
print("It takes %d steps to arrive at N = 1" % i)
# Out:
# 82
# The maximum value of N is 82
# 41.0
# The maximum value of N is 82
# 124.0
# The maximum value of N is 124
# 62.0
# The maximum value of N is 124
# 31.0
# The maximum value of N is 124
# 94.0
# The maximum value of N is 124
# 47.0
# The maximum value of N is 124
# 142.0
# The maximum value of N is 142
# 71.0
# The maximum value of N is 142
# 214.0
# The maximum value of N is 214
# 107.0
# The maximum value of N is 214
# 322.0
# The maximum value of N is 322
# 161.0
# The maximum value of N is 322
# 484.0
# The maximum value of N is 484
# 242.0
# The maximum value of N is 484
# 121.0
# The maximum value of N is 484
# 364.0
# The maximum value of N is 484
# 182.0
# The maximum value of N is 484
# 91.0
# The maximum value of N is 484
# 274.0
# The maximum value of N is 484
# 137.0
# The maximum value of N is 484
# 412.0
# The maximum value of N is 484
# 206.0
# The maximum value of N is 484
# 103.0
# The maximum value of N is 484
# 310.0
# The maximum value of N is 484
# 155.0
# ...
